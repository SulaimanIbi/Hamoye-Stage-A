# %% [markdown]
# ## Quiz Workbook
#
# This notebook contains the codes used in getting the answers to my quiz for the course: __Introduction to Python for Machine Learning__.

# %%
# import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid', {'grid.linestyle': '--'})


pd.options.display.max_rows = 15

# %%
# read in the data
data = pd.read_csv('fuel_data.csv')
data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# 5       f1_fuel_1994_12_2_0_13                 2         1994
# 6        f1_fuel_1994_12_2_1_1                 2         1994
# ...                        ...               ...          ...
# 29516   f1_fuel_2018_12_12_0_8                12         2018
# 29517  f1_fuel_2018_12_12_0_10                12         2018
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# ...

# %%
A = [1,2,3,4,5,6]
B = [13, 21, 34]
# A.extend(B)
A_B = A + B
A_B
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
# calculate the fuel type with the lowest average fuel_cost_per_unit_burned

fg = data.groupby('fuel_type_code_pudl')
fg.mean()['fuel_cost_per_unit_burned'].sort_values()
# Out:
# fuel_type_code_pudl
# gas          13.659397
# other        18.253856
# waste        19.518122
# coal         67.421830
# oil         168.877086
# nuclear    4955.157002
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
# find the standard deviation and the 75th percentile
data.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
# Kurtosis of the fuel_qty_burned feature
data['fuel_qty_burned'].kurtosis()
# Out:
# 651.3694501337732

# %%
data['fuel_unit'].value_counts(normalize=True, dropna=False)
# data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
180 / len(data)
# Out:
# 0.00609694136774718

# %%
# find the correlation of the fuel_cost_per_unit_burned with other features
data.corr()['fuel_cost_per_unit_burned'].sort_values(ascending=False)
# Out:
# fuel_cost_per_unit_burned       1.000000
# report_year                     0.013599
# fuel_cost_per_unit_delivered    0.011007
# fuel_cost_per_mmbtu            -0.000437
# fuel_mmbtu_per_unit            -0.010034
# fuel_qty_burned                -0.018535
# utility_id_ferc1               -0.037863
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
cyg = data[data['fuel_type_code_pudl'] == 'coal'].groupby('report_year')
cyg.mean()['fuel_cost_per_unit_burned']
# Out:
# report_year
# 1994     31.546467
# 1995     30.677442
# 1996     29.454299
# 1997    104.897309
# 1998     27.616234
# 1999     38.361101
# 2000    249.203055
#            ...
# 2012     53.657789
# 2013     55.093312
# 2014     52.244736
# 2015     49.769534
# 2016     46.447385
# 2017     45.983336
# 2018     44.967758
# Name: fuel_cost_per_unit_burned, Length: 25, dtype: float64

# %%
data.groupby('report_year').mean()['fuel_cost_per_unit_delivered'].sort_values(ascending=False)
# Out:
# report_year
# 1997    11140.197239
# 1996     9196.705948
# 2000      985.362877
# 2009      652.694163
# 2018      499.269966
# 2015      326.535511
# 1998      287.154420
#             ...
# 2002       47.594361
# 2017       46.196861
# 2007       43.325023
# 2005       41.438184
# 2006       38.657484
# 1995       32.735269
# 1999       25.551627
# Name: fuel_cost_per_unit_delivered, Length: 25, dtype: float64

# %%
yg = data[data['fuel_type_code_pudl'] == 'coal']
yg[yg['report_year'] == 1994].describe()
# Out:
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count        475.000000        475.0     4.750000e+02           475.000000
# mean         106.168421       1994.0     1.509912e+06            21.670377
# std           61.863101          0.0     2.330985e+06             3.701267
# min            1.000000       1994.0     1.586000e+03            11.526000
# 25%           46.000000       1994.0     3.851685e+05            17.788000
# 50%          113.000000       1994.0     8.568080e+05            22.814000
# 75%          159.000000       1994.0     1.699040e+06            24.832000
# max          201.000000       1994.0     3.506326e+07            27.542000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count                 475.000000                    475.000000
# mean                   31.546467                    124.663939
# std                    10.659393                   2068.684797
# ...
